# %% [markdown]
# # Interactive Plotting of Open Flight Data with Datashader

# %% [markdown]
# ## TODO
# * Plot full day of data
# * Try with short trail days
# * Use new agg files with categories and use for coloring

# %%
import bokeh
import bokeh.plotting as plotting
from bokeh.models import WMTSTileSource
plotting.output_notebook()
import datashader.transfer_functions as tf
import datashader as ds
from datashader.colors import viridis
from datashader.bokeh_ext import InteractiveImage
from datashader.utils import lnglat_to_meters as webm
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
ProgressBar().register()
import pandas as pd
import numpy as np
np.warnings.filterwarnings('ignore')
from sklearn.externals.joblib import Memory
memory = Memory(location='/tmp', verbose=0)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0a2facba-05cc-4e4c-b903-c69f28dd369a">Loading BokehJS ...</span>
#     </div>

# %%
print(f'Pandas version: {pd.__version__}')
print(f'Bokeh version: {bokeh.__version__}')
print(f'Datashader version: {ds.__version__}')
print(f'dask version: {dask.__version__}')
# Out:
# Pandas version: 0.23.4
# Bokeh version: 0.13.0
# Datashader version: 0.6.8
# dask version: 0.18.2

# %%
# %%time
parq_file = '/users/lukestarnes/Documents/adsb/2018_Feb.parq'
h5_file = '/users/lukestarnes/Documents/adsb/2018-06-19.h5'
ddf = dd.read_parquet(parq_file)
# ddf = pd.read_hdf(h5_file, stop=2_000_000, columns=['Lat', 'Long'])
# Out:
# CPU times: user 22.7 ms, sys: 6.95 ms, total: 29.6 ms
# Wall time: 41.4 ms

# %%
if 'x' not in ddf.columns:
    w = webm(ddf.Long, ddf.Lat)
    ddf.loc[:,'x'] = w[0]
    ddf.loc[:,'y'] = w[1]

# %%
MaxBounds = ((-20048966.10, 20048966.10), (-20026376.39, 20026376.39))
WholeWorld = ((-20_037_508, 20_037_508), (-7_670_608, 13_971_466))
TwoBounds = ((-20_000_000, 20_000_000), (-20_000_000, 20_000_000))
USA_CONUS = ((-13884029, -7453304), (2698291, 6455972))
WesternEuro = ((-1181114, 4270391), (3000000, 8081620))
Germany = ((709336, 1600000), (6026907, 7270000))
Chicago = (( -9828281, -9717659), (5096658, 5161298))
Chinatown = (( -9759210, -9754583), (5137122, 5139825))
NewYorkCity = (( -8280656, -8175066), (4940514, 4998954))
LosAngeles = ((-13195052, -13114944), (3979242, 4023720))
Houston = ((-10692703, -10539441), (3432521, 3517616))
Austin = ((-10898752, -10855820), (3525750, 3550837))
NewOrleans = ((-10059963, -10006348), (3480787, 3510555))
Atlanta = ((-9507853,-9274873), (3927030, 4069506))

# %%
# source: https://leaflet-extras.github.io/leaflet-providers/preview/
Esri_NatGeoWorldMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
Esri_OceanBasemap = 'https://server.arcgisonline.com/ArcGIS/rest/services/Ocean_Basemap/MapServer/tile/{z}/{y}/{x}'
CartoDB_Positron = 'https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}{r}.png'
CartoDB_Voyager = 'https://cartodb-basemaps-{s}.global.ssl.fastly.net/rastertiles/voyager/{z}/{x}/{y}{r}.png'
OpenStreetMap_Mapnik = 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png'
OpenTopoMap = 'https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png'
Hydda_Full = 'https://{s}.tile.openstreetmap.se/hydda/full/{z}/{x}/{y}.png'
Esri_WorldStreetMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}'
Esri_WorldTopoMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}'
Esri_WorldImagery = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}'

# %%
def spread(pts):
    return ((pts[0][1] - pts[0][0]),
            (pts[1][1] - pts[1][0]))
def ratio(pts):
    s = spread(pts)
    x, y = s
    return x / y

# %%
def base_plot(xrange, yrange, plot_width=int(900), plot_height=int(500),
              tools='pan,wheel_zoom,zoom_in,zoom_out,reset', 
              bok_cir = True, tile_url=CartoDB_Positron):
    p = plotting.figure(tools=tools,
                  plot_width=plot_width, plot_height=plot_height,
                  x_range=(xrange), y_range=yrange, outline_line_color=None,
                  min_border=0, min_border_left=0, min_border_right=0,
                  min_border_top=0, min_border_bottom=0)
    p.match_aspect = True
    p.axis.visible = False
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    if bok_cir:
        p.circle(x="x", y="y",color='red', size=2, alpha=0.4) 
    tile_renderer = p.add_tile(WMTSTileSource(url=tile_url)) 
    tile_renderer.alpha=0.8
    return p

# %%
@memory.cache
def create_image(x_range, y_range, plot_width, plot_height, thresh=None):
    cmap=viridis
    color_key={'w':'blue', 'b':'green', 'a':'red', 'h':'orange', 'o':'saddlebrown'}
    cvs = ds.Canvas(plot_width, plot_height, x_range, y_range)
    agg = cvs.points(ddf, 'x', 'y', ds.count_cat('Cou'))
    if thresh is not None:
        img = tf.shade(agg.where(agg > thresh), cmap = cmap, color_key=color_key)
    else:
        img = tf.shade(agg, cmap = cmap)
    return img

def image_callback(xr, yr, w, h):
    return create_image(xr, yr, w, h, thresh=thold)

# %%
thold = None
p = base_plot(*WholeWorld, bok_cir=False, tile_url=Esri_NatGeoWorldMap)
InteractiveImage(p, image_callback)
# Out:
#   <div class="bk-root" id="a7da89ae-e3c0-4b22-b04c-068e6c03e7db"></div>
#
# <script type="text/javascript">
#   (function(root) {
#   function embed_document(root) {
#
#   var docs_json = {"3cb9b80b-3ea7-49ac-adcb-a8cf247dbfdc":{"roots":{"references":[{"attributes":{},"id":"1ce0e45f-f150-4bf2-a366-8b6b09c2e759","type":"ZoomInTool"},{"attributes":{},"id":"3e1d404f-8c2c-4eec-8fdb-67c8b0df0792","type":"BasicTickFormatter"},{"attributes":{},"id":"be099a21-8c1b-44e5-84a6-2d33eff08b69","type":"ZoomOutTool"},{"attributes":{"plot":null,"text":""},"id":"f73684d1-35d2-4e15-ba68-e33c1b82bb5e","type":"Title"},{"attributes":{},"id":"7da15a0c-8c91-411b-909e-5ead850985e1","type":"PanTool"},{"attributes":{"callback":null,"data":{"dh":[21642074],"dw":[40075016],"image":[{"__ndarray__":"...","dtype":"uint32","shape":[500,900]}],"x":[-20037508],"y":[-7670608]},"selected":{"id":"636c3a4d-3fe5-4e4a-aeab-361062f0ac3c","type":"Selection"},"selection_policy":{"id":"a1aea8d0-5633-4581-89ad-57ddfabe3cab","type":"UnionRenderers"}},"id":"f8ee4127-f1c0-4c98-8396-50d910c1fb49","type":"ColumnDataSource"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a4bd9df9-d376-4748-a5f8-ee32721a7420","type":"ImageRGBA"},{"attributes":{},"id":"b94e1211-fd4b-4297-94d9-db3bdf6dd15c","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"f8ee4127-f1c0-4c98-8396-50d910c1fb49","type":"ColumnDataSource"}},"id":"98401658-c969-4b05-88e6-f4831b7dd4f2","type":"CDSView"},{"attributes":{},"id":"d51af0b4-d2bb-4dfc-b9d8-9935bbce87ef","type":"ResetTool"},{"attributes":{"alpha":0.8,"tile_source":{"id":"c636eb34-df3f-45cc-8c99-a873ad1b3228","type":"WMTSTileSource"}},"id":"46403c5e-d8fa-4f15-8816-1024e97163e4","type":"TileRenderer"},{"attributes":{"formatter":{"id":"b94e1211-fd4b-4297-94d9-db3bdf6dd15c","type":"BasicTickFormatter"},"plot":{"id":"24f191b6-864d-44d0-8158-760f8bfe2099","subtype":"Figure","type":"Plot"},"ticker":{"id":"77f17b89-d2f1-4501-8dbb-e0128d310278","type":"BasicTicker"},"visible":false},"id":"cfa244bf-22be-451a-98cc-5f1c4f73ffcf","type":"LinearAxis"},{"attributes":{},"id":"ec41e99d-784b-415a-98cf-4863e933fc4c","type":"BasicTicker"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"061224e8-4f39-4732-9ae8-da39e64b827c","type":"ImageRGBA"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"7da15a0c-8c91-411b-909e-5ead850985e1","type":"PanTool"},{"id":"0b032479-6a97-411d-b016-6d887ec7c8b6","type":"WheelZoomTool"},{"id":"1ce0e45f-f150-4bf2-a366-8b6b09c2e759","type":"ZoomInTool"},{"id":"be099a21-8c1b-44e5-84a6-2d33eff08b69","type":"ZoomOutTool"},{"id":"d51af0b4-d2bb-4dfc-b9d8-9935bbce87ef","type":"ResetTool"}]},"id":"a6953a14-905d-4625-b47f-4e119c28409b","type":"Toolbar"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"24f191b6-864d-44d0-8158-760f8bfe2099","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec41e99d-784b-415a-98cf-4863e933fc4c","type":"BasicTicker"}},"id":"28f9dd00-f525-44ac-afbd-e126f76cce97","type":"Grid"},{"attributes":{"callback":{"id":"7191d3ae-3fbe-49e6-9da6-5508b565afd5","type":"CustomJS"},"end":20037508,"start":-20037508},"id":"f516d9a7-e42f-4bb6-8cd9-b37d067942e1","type":"Range1d"},{"attributes":{},"id":"636c3a4d-3fe5-4e4a-aeab-361062f0ac3c","type":"Selection"},{"attributes":{},"id":"37b5e219-371c-41d4-93f5-612f120e4573","type":"LinearScale"},{"attributes":{},"id":"6578692a-5007-4c22-ac66-3f70e5b7bf40","type":"LinearScale"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"24f191b6-864d-44d0-8158-760f8bfe2099","subtype":"Figure","type":"Plot"},"ticker":{"id":"77f17b89-d2f1-4501-8dbb-e0128d310278","type":"BasicTicker"}},"id":"5523bc79-695f-4099-abb3-3f8a37f6b8aa","type":"Grid"},{"attributes":{"formatter":{"id":"3e1d404f-8c2c-4eec-8fdb-67c8b0df0792","type":"BasicTickFormatter"},"plot":{"id":"24f191b6-864d-44d0-8158-760f8bfe2099","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec ...
