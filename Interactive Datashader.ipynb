# %% [markdown]
# # Interactive Plotting of Open Flight Data with Datashader

# %% [markdown]
# ## TODO
# * Plot full day of data
# * Try with short trail days
# * Use new agg files with categories and use for coloring

# %%
import bokeh
import bokeh.plotting as plotting
from bokeh.models import WMTSTileSource
plotting.output_notebook()
import datashader.transfer_functions as tf
import datashader as ds
from datashader.colors import viridis
from datashader.bokeh_ext import InteractiveImage
from datashader.utils import lnglat_to_meters as webm
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
ProgressBar().register()
import pandas as pd
import numpy as np
np.warnings.filterwarnings('ignore')
from sklearn.externals.joblib import Memory
memory = Memory(location='/tmp', verbose=0)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c69fead1-6a2a-4bcc-b73d-dea2caca02c5">Loading BokehJS ...</span>
#     </div>

# %%
print(f'Pandas version: {pd.__version__}')
print(f'Bokeh version: {bokeh.__version__}')
print(f'Datashader version: {ds.__version__}')
print(f'dask version: {dask.__version__}')
# Out:
# Pandas version: 0.23.4
# Bokeh version: 0.13.0
# Datashader version: 0.6.8
# dask version: 0.18.2

# %%
import datetime as dt
import logging
now = dt.datetime.now().strftime('%m-%d-%y_%H%M%S')
logging.basicConfig(filename=now+".log", level=logging.INFO, format='%(asctime)s %(message)s')

# %%
# %%time
parq_file = '/users/lukestarnes/Documents/adsb/2018_Feb.parq'
h5_file = '/users/lukestarnes/Documents/adsb/2018-06-19.h5'
ddf = dd.read_parquet(parq_file)
# ddf = pd.read_hdf(h5_file, stop=2_000_000, columns=['Lat', 'Long'])
# Out:
# CPU times: user 23 ms, sys: 6.97 ms, total: 30 ms
# Wall time: 36.7 ms

# %%
if 'x' not in ddf.columns:
    w = webm(ddf.Long, ddf.Lat)
    ddf.loc[:,'x'] = w[0]
    ddf.loc[:,'y'] = w[1]

# %%
f'Row Count: {len(ddf):,}'
# Out:
# [########################################] | 100% Completed |  1min 57.1s
# 'Row Count: 377,051,964'

# %%
MaxBounds = ((-20048966.10, 20048966.10), (-20026376.39, 20026376.39))
WholeWorld = ((-20_037_508, 20_037_508), (-7_670_608, 13_971_466))
TwoBounds = ((-20_000_000, 20_000_000), (-20_000_000, 20_000_000))
USA_CONUS = ((-13884029, -7453304), (2698291, 6455972))
WesternEuro = ((-1181114, 4270391), (3000000, 8081620))
Germany = ((709336, 1600000), (6026907, 7270000))
Chicago = (( -9828281, -9717659), (5096658, 5161298))
Chinatown = (( -9759210, -9754583), (5137122, 5139825))
NewYorkCity = (( -8280656, -8175066), (4940514, 4998954))
LosAngeles = ((-13195052, -13114944), (3979242, 4023720))
Houston = ((-10692703, -10539441), (3432521, 3517616))
Austin = ((-10898752, -10855820), (3525750, 3550837))
NewOrleans = ((-10059963, -10006348), (3480787, 3510555))
Atlanta = ((-9507853,-9274873), (3927030, 4069506))

# %%
# source: https://leaflet-extras.github.io/leaflet-providers/preview/
Esri_NatGeoWorldMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
Esri_OceanBasemap = 'https://server.arcgisonline.com/ArcGIS/rest/services/Ocean_Basemap/MapServer/tile/{z}/{y}/{x}'
CartoDB_Positron = 'https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}{r}.png'
CartoDB_Voyager = 'https://cartodb-basemaps-{s}.global.ssl.fastly.net/rastertiles/voyager/{z}/{x}/{y}{r}.png'
OpenStreetMap_Mapnik = 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png'
OpenTopoMap = 'https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png'
Hydda_Full = 'https://{s}.tile.openstreetmap.se/hydda/full/{z}/{x}/{y}.png'
Esri_WorldStreetMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}'
Esri_WorldTopoMap = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}'
Esri_WorldImagery = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}'

# %%
def spread(pts):
    return ((pts[0][1] - pts[0][0]),
            (pts[1][1] - pts[1][0]))
def ratio(pts):
    s = spread(pts)
    x, y = s
    return x / y

# %%
def base_plot(xrange, yrange, plot_width=int(900), plot_height=int(500),
              tools='pan,wheel_zoom,zoom_in,zoom_out,reset', 
              bok_cir = True, tile_url=CartoDB_Positron):
    p = plotting.figure(tools=tools,
                  plot_width=plot_width, plot_height=plot_height,
                  x_range=(xrange), y_range=yrange, outline_line_color=None,
                  min_border=0, min_border_left=0, min_border_right=0,
                  min_border_top=0, min_border_bottom=0)
    p.match_aspect = True
    p.axis.visible = False
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    if bok_cir:
        p.circle(x="x", y="y",color='red', size=2, alpha=0.4) 
    tile_renderer = p.add_tile(WMTSTileSource(url=tile_url)) 
    tile_renderer.alpha=0.8
    return p

# %%
@memory.cache
def create_image(x_range, y_range, plot_width, plot_height, thresh=None):
    logging.info(f'Create Image - {x_range}, {y_range}')
    cmap=viridis
#     color_key={'United States':'blue', 'Germany':'green', 'United Kingdom':'red', 
#                'Canada':'orange', 'China':'purple', 'Australia':'yellow',
#                'Japan':'white', 'Other':'saddlebrown'}
    color_key = ['blue', 'green', 'red', 'orange', 'purple', 'yellow', 'white', 'saddlebrown']
    cvs = ds.Canvas(plot_width, plot_height, x_range, y_range)
    agg = cvs.points(ddf, 'x', 'y', ds.count_cat('Cou'))
    if thresh is not None:
        img = tf.shade(agg.where(agg > thresh), cmap = cmap, color_key=color_key)
    else:
        img = tf.shade(agg, cmap = cmap, color_key=color_key)
    img = tf.dynspread(img, threshold=0.5, max_px=4)
    logging.info(f'Image Generated')
    return img 

def image_callback(xr, yr, w, h):
    logging.info(f'Callback')
    return create_image(xr, yr, w, h, thresh=thold)

# %%
thold = None
p = base_plot(*WholeWorld, bok_cir=False, tile_url=Esri_NatGeoWorldMap)
logging.info(f'InteractiveImage Start')
InteractiveImage(p, image_callback)
# Out:
# [########################################] | 100% Completed | 11.5s
# [########################################] | 100% Completed |  2min  0.1s
#   <div class="bk-root" id="60814190-1ef6-435d-bf68-d7a321d6d433"></div>
#
# <script type="text/javascript">
#   (function(root) {
#   function embed_document(root) {
#
#   var docs_json = {"96531aef-6284-4f9c-a014-eeb727aa39af":{"roots":{"references":[{"attributes":{},"id":"b7cc40a7-de07-4bad-bf77-ba30e743efc8","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"72da8c87-aecd-4cce-89bc-a775d53f2e8d","type":"Title"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d41260e3-c8f8-477d-b099-09936d228f26","type":"ImageRGBA"},{"attributes":{"formatter":{"id":"98373527-d71c-4ba3-9c92-2e065d033317","type":"BasicTickFormatter"},"plot":{"id":"8e08724d-88c7-4271-9b1e-6935a5c63054","subtype":"Figure","type":"Plot"},"ticker":{"id":"81543309-a3ac-49b5-b254-b7b79d65ca1b","type":"BasicTicker"},"visible":false},"id":"861827ea-30e7-4e3c-baa1-29497def6c16","type":"LinearAxis"},{"attributes":{},"id":"9fda18ad-47f0-4837-9504-586ca1ddc054","type":"WheelZoomTool"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"8e08724d-88c7-4271-9b1e-6935a5c63054","subtype":"Figure","type":"Plot"},"ticker":{"id":"12d8c884-e5a4-4d73-a007-c3095f6e3e8b","type":"BasicTicker"}},"id":"425ed468-b498-4047-8dbd-09d61a7c3058","type":"Grid"},{"attributes":{"callback":{"id":"f770885e-c7cf-4388-84e6-73268b63b053","type":"CustomJS"},"end":13971466,"start":-7670608},"id":"cf25f63f-22e2-494b-9951-c572647de583","type":"Range1d"},{"attributes":{"args":{"x_range":{"id":"5c2871f1-d168-4e71-a90b-9e7a7b8e0c1e","type":"Range1d"},"y_range":{"id":"cf25f63f-22e2-494b-9951-c572647de583","type":"Range1d"}},"code":"\n        // Define a callback to capture errors on the Python side\n        function callback(msg){\n          if (msg.msg_type == \"execute_result\") {\n            if (msg.content.data['text/plain'] === \"'Complete'\") {\n               if (Bokeh._queued.length) {\n                   console.log(Date().toString() + \" - Update Plot\")\n                   update_plot()\n                   console.log(Date().toString() + \" - Plot Updates\");\n               } else {\n                   Bokeh._blocked = false;\n               }\n               Bokeh._timeout = Date.now();\n            }\n          }// else {\n          //  console.log(\"Python callback returned unexpected message:\", msg)\n          //}\n        }\n        callbacks = {iopub: {output: callback}};\n\n        function update_plot() {\n            range = Bokeh._queued;\n            var cmd = \"from datashader.bokeh_ext import InteractiveImage; InteractiveImage._callbacks['0b55aa1b-470f-490c-a5f4-2ed129e43061'].update(\" + range + \")\"\n            // Execute the command on the Python kernel\n            if (IPython.notebook.kernel !== undefined) {\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(cmd, callbacks, {silent : false});\n            }\n            Bokeh._queued = [];\n        }\n\n        var plot = x_range.plots[0];\n        // Generate a command to execute in Python\n        var ranges = {xmin: x_range.start,\n                       ymin: y_range.start,\n                       xmax: x_range.end,\n                       ymax: y_range.end,\n                       w: Math.floor(plot.width),\n                       h: Math.floor(plot.height)}\n        var range_str = JSON.stringify(ranges)\n        console.log(Date().toString() + \" - Xrange, Yrange, W, H: \" + range_str)\n\n        if (!Bokeh._queued) {\n            Bokeh._queued = [];\n            Bokeh._blocked = false;\n            Bokeh._timeout = Date.now();\n        }\n\n        timeout = Bokeh._timeout + 2000;\n        if (typeof _ === \"undefined\") {\n        } else if ((Bokeh._blocked && (Date.now() < timeout))) {\n            Bokeh._queued = [range_str];\n        } else {\n            Bokeh._queued = [range_str];\n            setTimeout(update_plot(), 200);\n            Bokeh._blocked = true;\n            Bokeh._timeout = Date.now();\n        }\n    "},"id":"f770885e-c7cf-4388-84e6-73268b63b053","type":"CustomJS"},{"attributes":{}, ...
